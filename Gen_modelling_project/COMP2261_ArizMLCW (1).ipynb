# %% [markdown]
# # **Multimodal Machine Learning with Brain, Image, and Text Data**
#
# This notebook provides a comprehensive guide to training machine learning models using multimodal data, including brain signals, images, and text. You will explore various data processing techniques, model training using neural networks and traditional classifiers, and performance evaluation using metrics like accuracy, precision, and recall. The goal is to integrate diverse data sources to improve classification performance and gain deeper insights into complex datasets.

# %% [markdown]
# # **Install the package**

# %% [markdown]
# ##**1. Install the data reading package**

# %% [markdown]
# **Library Installation**:
#
# The code first installs the required library, mmbra, using the command pip install mmbra, and pip install mmbracategories. This step ensures that all the necessary dependencies for this specific library are available in the environment. The installation process is critical for using the functionalities provided by the mmbra package and mmbracategories package in subsequent steps.
#
# **Library Import**:
#
# After the installation, imports the mmbra module and mmbracategories module. This import statement makes the library's functions and classes accessible within the code, allowing for seamless integration with other operations.

# %%
# !pip install mmbra
# !pip install mmbracategories
import mmbra
import mmbracategories
# Out:
# Requirement already satisfied: mmbra in /usr/local/lib/python3.12/dist-packages (0.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from mmbra) (2.9.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->mmbra) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->mmbra) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->mmbra) (3.0.3)
# Requirement already satisfied: mmbracategories in /usr/local/lib/python3.12/dist-packages (0.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from mmbracategories) (2.9.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->mmbracategories) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->mmbracategories) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->mmbracategories) (3.0.3)

# %% [markdown]
# ##**3. Dataset split settings**

# %% [markdown]
# In this section, we are loading and preparing the brain, image, and text data for subsequent analysis by organizing the datasets and converting them into a format compatible with PyTorch. Here's a step-by-step description of the key operations:
#
# **Data Loading**:
#
# The code first sets up the data directories by constructing paths for different datasets, including brain, image, and text features. It organizes these paths based on the subject identifier, data type (training or testing), and the model used (e.g., image and text models).
# The datasets are loaded from .mat files using the scipy.io.loadmat() function. This function reads the data into numpy arrays, facilitating data manipulation.
#
# **Data Preprocessing**:
#
# For the brain data, specific time intervals are extracted (70ms-400ms), and the data is reshaped to a two-dimensional format to simplify analysis.
# Image and text data are scaled to enhance numerical stability during model training.
# Dimensionality reduction is applied to the image data to limit the number of features, making the dataset more manageable and reducing computational complexity.
#
# **Conversion to PyTorch Tensors**:
#
# The numpy arrays for each dataset (brain, image, text, and labels) are converted into PyTorch tensors. This conversion is crucial for efficient data handling in neural network training, as tensors are optimized for operations on GPU.
#
# **Data Summary**:
#
# The code prints the shape of each dataset, providing an overview of the number of samples and features for both training and testing sets. This summary helps confirm that the data is correctly formatted and that the expected number of features is present.
# This process of data loading, preprocessing, and conversion into PyTorch tensors ensures that the brain, image, and text datasets are ready for further analysis or machine learning tasks.

# %%
import torch
import os
import scipy.io as sio
from sklearn.model_selection import train_test_split
import numpy as np

# load data
data_dir_root = os.path.join('./data', 'ThingsEEG-Text')
sbj = 'sub-10'
image_model = 'pytorch/cornet_s'
text_model = 'CLIPText'
roi = '17channels'
brain_dir = os.path.join(data_dir_root, 'brain_feature', roi, sbj)
image_dir_seen = os.path.join(data_dir_root, 'visual_feature/ThingsTrain', image_model, sbj)
image_dir_unseen = os.path.join(data_dir_root, 'visual_feature/ThingsTest', image_model, sbj)
text_dir_seen = os.path.join(data_dir_root, 'textual_feature/ThingsTrain/text', text_model, sbj)
text_dir_unseen = os.path.join(data_dir_root, 'textual_feature/ThingsTest/text', text_model, sbj)

brain_seen = sio.loadmat(os.path.join(brain_dir, 'eeg_train_data_within.mat'))['data'].astype('double') * 2.0
brain_seen = brain_seen[:,:,27:60] # 70ms-400ms
brain_seen = np.reshape(brain_seen, (brain_seen.shape[0], -1))
image_seen = sio.loadmat(os.path.join(image_dir_seen, 'feat_pca_train.mat'))['data'].astype('double')*50.0
text_seen = sio.loadmat(os.path.join(text_dir_seen, 'text_feat_train.mat'))['data'].astype('double')*2.0
label_seen = sio.loadmat(os.path.join(brain_dir, 'eeg_train_data_within.mat'))['class_idx'].T.astype('int')
image_seen = image_seen[:,0:100]

brain_unseen = sio.loadmat(os.path.join(brain_dir, 'eeg_test_data.mat'))['data'].astype('double')*2.0
brain_unseen = brain_unseen[:, :, 27:60]
brain_unseen = np.reshape(brain_unseen, (brain_unseen.shape[0], -1))
image_unseen = sio.loadmat(os.path.join(image_dir_unseen, 'feat_pca_test.mat'))['data'].astype('double')*50.0
text_unseen = sio.loadmat(os.path.join(text_dir_unseen, 'text_feat_test.mat'))['data'].astype('double')*2.0
label_unseen = sio.loadmat(os.path.join(brain_dir, 'eeg_test_data.mat'))['class_idx'].T.astype('int')
image_unseen = image_unseen[:, 0:100]

brain_seen = torch.from_numpy(brain_seen)
brain_unseen = torch.from_numpy(brain_unseen)
image_seen = torch.from_numpy(image_seen)
image_unseen = torch.from_numpy(image_unseen)
text_seen = torch.from_numpy(text_seen)
text_unseen = torch.from_numpy(text_unseen)
label_seen = torch.from_numpy(label_seen)
label_unseen = torch.from_numpy(label_unseen)

print('seen_brain_samples=', brain_seen.shape[0], ', seen_brain_features=', brain_seen.shape[1])
print('seen_image_samples=', image_seen.shape[0], ', seen_image_features=', image_seen.shape[1])
print('seen_text_samples=', text_seen.shape[0], ', seen_text_features=', text_seen.shape[1])
print('seen_label=', label_seen.shape)
print('unseen_brain_samples=', brain_unseen.shape[0], ', unseen_brain_features=', brain_unseen.shape[1])
print('unseen_image_samples=', image_unseen.shape[0], ', unseen_image_features=', image_unseen.shape[1])
print('unseen_text_samples=', text_unseen.shape[0], ', unseen_text_features=', text_unseen.shape[1])
print('unseen_label=', label_unseen.shape)
# Out:
# seen_brain_samples= 16540 , seen_brain_features= 561
# seen_image_samples= 16540 , seen_image_features= 100
# seen_text_samples= 16540 , seen_text_features= 512
# seen_label= torch.Size([16540, 1])
# unseen_brain_samples= 16000 , unseen_brain_features= 561
# unseen_image_samples= 16000 , unseen_image_features= 100
# unseen_text_samples= 16000 , unseen_text_features= 512
# unseen_label= torch.Size([16000, 1])

# %%
label_unseen
# Out:
# tensor([[  1],
#         [  2],
#         [  3],
#         ...,
#         [198],
#         [199],
#         [200]])

# %%
mmbracategories.print_seen_categories()
# Out:
# 00001_aardvark
# 00002_abacus
# 00003_accordion
# 00004_acorn
# 00005_air_conditioner
# 00006_air_mattress
# 00007_air_pump
# 00008_airbag
# 00009_airboat
# 00010_airplane
# 00011_album
# 00012_alligator
# 00013_almond
# 00014_aloe
# 00015_alpaca
# 00016_altar
# 00017_aluminum_foil
# 00018_amber
# 00019_ambulance
# 00020_amplifier
# 00021_anchor
# 00022_ankle
# 00023_anklet
# 00024_ant
# 00025_anteater
# 00026_antenna
# 00027_anvil
# 00028_appetizer
# 00029_apple
# 00030_apple_tree
# 00031_applesauce
# 00032_apron
# 00033_aquarium
# 00034_arch
# 00035_arm
# 00036_armor
# 00037_arrow
# 00038_artichoke
# 00039_arugula
# 00040_ashtray
# 00041_asparagus
# 00042_avocado
# 00043_awning
# 00044_axe
# 00045_baby
# 00046_backdrop
# 00047_backgammon
# 00048_backpack
# 00049_bacon
# 00050_badge
# 00051_badger
# 00052_bag
# 00053_bagel
# 00054_bagpipe
# 00055_baklava
# 00056_ball
# 00057_balloon
# 00058_ballot_box
# 00059_bamboo
# 00060_banana_peel
# 00061_banana_split
# 00062_bandage
# 00063_bandanna
# 00064_banjo
# 00065_bank
# 00066_banner
# 00067_barbed_wire
# 00068_barbell
# 00069_barcode
# 00070_bark
# 00071_barnacle
# 00072_barrel
# 00073_barrette
# 00074_baseball
# 00075_baseball_glove
# 00076_basket
# 00077_basketball_hoop
# 00078_bassinet
# 00079_bat1
# 00080_bat2
# 00081_bathmat
# 00082_bathrobe
# 00083_bathtub
# 00084_baton1
# 00085_baton2
# 00086_baton3
# 00087_battery
# 00088_bazooka
# 00089_beachball
# 00090_bead
# 00091_beaker
# 00092_bean
# 00093_beanbag
# 00094_beanie
# 00095_bear
# 00096_beard
# 00097_bed
# 00098_bedpan
# 00099_bedpost
# 00100_bee
# 00101_beehive
# 00102_beer
# 00103_beet
# 00104_beetle
# 00105_bell
# 00106_bell_pepper
# 00107_belt
# 00108_belt_buckle
# 00109_berry
# 00110_bib
# 00111_bikini
# 00112_bin
# 00113_binder
# 00114_binoculars
# 00115_bird
# 00116_birdbath
# 00117_birdcage
# 00118_birdhouse
# 00119_biscuit
# 00120_bison
# 00121_blackberry
# 00122_blanket
# 00123_blazer
# 00124_blender
# 00125_blimp
# 00126_blind
# 00127_blinder
# 00128_blindfold
# 00129_block
# 00130_blouse
# 00131_blower
# 00132_blowfish
# 00133_blowgun
# 00134_blueberry
# 00135_boa
# 00136_boar
# 00137_board
# 00138_board_game
# 00139_bobsled
# 00140_bolo_tie
# 00141_bologna
# 00142_bolt
# 00143_bomb
# 00144_bone
# 00145_bongo
# 00146_bonsai
# 00147_book
# 00148_bookmark
# 00149_bookshelf
# 00150_boomerang
# 00151_boot
# 00152_bottle
# 00153_boulder
# 00154_bouquet
# 00155_bow1
# 00156_bow2
# 00157_bow3
# 00158_bowl
# 00159_bowler_hat
# 00160_bowling_ball
# 00161_bowtie
# 00162_box
# 00163_boxer_shorts
# 00164_boxing_gloves
# 00165_boy
# 00166_bra
# 00167_bracelet1
# 00168_bracelet2
# 00169_bracket
# 00170_braid
# 00171_brake
# 00172_branch
# 00173_brass_knuckles
# 00174_breadstick
# 00175_breakfast
# 00176_breathalyzer
# 00177_brick
# 00178_briefcase
# 00179_broccoli
# 00180_brooch
# 00181_broom
# 00182_brownie
# 00183_brush
# 00184_brussels_sprouts
# 00185_bubble
# 00186_bubble_wrap
# 00187_bucket
# 00188_buckle
# 00189_buffet
# 00190_bull
# 00191_bulldozer
# 00192_bulletin_board
# 00193_bulletproof_vest
# 00194_bumper
# 00195_bungee
# 00196_bunkbed
# 00197_buoy
# 00198_burner
# 00199_burrito
# 00200_bus
# 00201_butter
# 00202_butterfly
# 00203_button1
# 00204_button2
# 00205_cabbage
# 00206_cabinet
# 00207_cable
# 00208_cactus
# 00209_cage
# 00210_cake
# 00211_cake_mix
# 00212_calculator
# 00213_calf1
# 00214_calf2
# 00215_calzone
# 00216_camcorder
# 00217_camel
# 00218_camera1
# 00219_camera2
# 00220_camera_lens
# 00221_camper
# 00222_can
# 00223_can_opener
# 00224_candelabra
# 00225_candle
# 00226_candy
# 00227_candy_bar
# 00228_candy_cane
# 00229_cane
# 00230_canister
# 00231_cannon
# 00232_cannonball
# 00233_canoe
# 00234_cantaloupe
# 00235_canvas
# 00236_cap
# 00237_cape
# 00238_car
# 00239_car_door
# 00240_car_seat
# 00241_caramel
# 00242_card
# 00243_cardboard
# 00244_cardigan
# 00245_cardinal
# 00246_carousel
# 00247_carriage
# 00248_carrot
# 00249_cash_machine
# 00250_cash_register
# 00251_casserole
# 00252_cassette
# 00253_catapult
# 00254_catfish
# 00255_cauliflower
# 00256_caviar
# 00257_celery
# 00258_cello
# 00259_cellphone
# 00260_cement_mixer
# 00261_centerpiece
# 00262_centrifuge
# 00263_cereal
# 00264_chainsaw
# 00265_chair
# 00266_chalice
# 00267_chalk
# 00268_chalkboard
# 00269_champagne
# 00270_chandelier
# 00271_charcoal
# 00272_charger
# 00273_chariot
# 00274_checkbook
# 00275_checkers
# 00276_cheeseburger
# 00277_cheesecake
# 00278_cherry
# 00279_chess_piece
# 00280_chessboard
# 00281_chest1
# 00282_chick
# 00283_chicken1
# 00284_chicken2
# 00285_chicken_wire
# 00286_chickpea
# 00287_chihuahua
# 00288_chili
# 00289_chimney
# 00290_chin
# 00291_chinaware
# 00292_chinchilla
# 00293_chip
# 00294_chipmunk
# 00295_chips
# 00296_chisel
# 00297_chive
# 00298_chocolate
# 00299_christmas_card
# 00300_christmas_tree
# 00301_chute
# 00302_cigar
# 00303_cigarette
# 00304_cigarette_butt
# 00305_cigarette_holder
# 00306_cilantro
# 00307_cinnamon
# 00308_clam
# 00309_clarinet
# 00310_clasp
# 00311_clay
# 00312_clipboard
# 00313_clipper1
# 00314_clipper2
# 00315_cloak
# 00316_clock
# 00317_closet
# 00318_clothes
# 00319_clothesline
# 00320_clothespin
# 00321_cloud
# 00322_clove
# 00323_clover
# 00324_coal
# 00325_coaster
# 00326_coat_rack
# 00327_cockatoo
# 00328_cockroach
# 00329_cocktail
# 00330_cocoon
# 00331_coffee
# 00332_coffee_filter
# 00333_coffee_pot
# 00334_coffee_table
# 00335_coffin
# 00336_coil
# 00337_coin
# 00338_coleslaw
# 00339_collar
# 00340_column
# 00341_comb
# 00342_combination_lock
# 00343_comic_book
# 00344_compass
# 00345_compost
# 00346_computer
# 00347_computer_screen
# 00348_confetti
# 00349_contact_lens
# 00350_container
# 00351_cooker
# 00352_cookie_cutter
# 00353_cookie_sheet
# 00354_cooler
# 00355_coop
# 00356_copier
# 00357_coral
# 00358_cord
# 00359_cork
# 00360_corkboard
# 00361_corkscrew
# 00362_corn
# 00363_cornbread
# 00364_cornhusk
# 00365_cornmeal
# 00366_cornucopia
# 00367_corsage
# 00368_corset
# 00369_costume
# 00370_cot
# 00371_cotton_candy
# 00372_couch
# 00373_cougar
# 00374_counter
# 00375_cow
# 00376_coyote
# 00377_cracker
# 00378_cranberry
# 00379_crane
# 00380_crank
# 00381_crate
# 00382_crayfish
# 00383_crayon
# 00384_cream
# 00385_cream_cheese
# 00386_credit_card
# 00387_cross
# 00388_crossbow
# 00389_crouton
# 00390_crowbar
# 00391_crown
# 00392_crucifix
# 00393_crutch
# 00394_crystal1
# 00395_crystal2
# 00396_crystal_ball
# 00397_cuckoo_clock
# 00398_cucumber
# 00399_cufflink
# 00400_cummerbund
# 00401_cup
# 00402_curb
# 00403_curling_iron
# 00404_curry
# 00405_curtain
# 00406_cushion
# 00407_cutting_board
# 00408_cymbal
# 00409_daisy
# 00410_dandelion
# 00411_dart
# 00412_dartboard
# 00413_dashboard
# 00414_deer
# 00415_defibrillator
# 00416_denture
# 00417_deodorant
# 00418_desk
# 00419_detonator
# 00420_dial
# 00421_diamond
# 00422_diaper
# 00423_dice
# 00424_dip
# 00425_dirt_bike
# 00426_dish
# 00427_dishrag
# 00428_dishwasher
# 00429_dishwashing_liquid
# 00430_diskette
# 00431_diving_board
# 00432_dog
# 00433_dogfood
# 00434_doghouse
# 00435_doily
# 00436_doll
# 00437_dollhouse
# 00438_dolly
# 00439_dolphin
# 00440_domino
# 00441_donkey
# 00442_donut
# 00443_door
# 00444_doorbell
# 00445_doorhandle
# 00446_doorknob
# 00447_doorknocker
# 00448_doormat
# 00449_doorstop
# 00450_dough
# 00451_drain
# 00452_drawer
# 00453_dress
# 00454_dresser
# 00455_drill
# 00456_drink
# 00457_drumstick
# 00458_dryer
# 00459_duck
# 00460_duckling
# 00461_duct
# 00462_duct_tape
# 00463_dumbbell
# 00464_dumbwaiter
# 00465_dumpling
# 00466_dumpster
# 00467_duster
# 00468_dustpan
# 00469_dynamite
# 00470_ear
# 00471_earplug
# 00472_earring
# 00473_earwig
# 00474_easel
# 00475_easter_egg
# 00476_eclair
# 00477_egg_roll
# 00478_eggbeater
# 00479_eggnog
# 00480_eggplant
# 00481_eggshell
# 00482_elbow
# 00483_electric_chair
# 00484_emerald
# 00485_enchilada
# 00486_engine
# 00487_envelope
# 00488_eraser
# 00489_exerciser
# 00490_exhaust_pipe
# 00491_extinguisher
# 00492_eye
# 00493_eye_patch
# 00494_eyedropper
# 00495_eyeliner
# 00496_eyepiece
# 00497_face
# 00498_fan
# 00499_fast_food
# 00500_faucet
# 00501_feather
# 00502_fence
# 00503_fencepost
# 00504_fern
# 00505_ferret
# 00506_ferris_wheel
# 00507_fig
# 00508_figurine
# 00509_file1
# 00510_file2
# 00511_filing_cabinet
# 00512_film
# 00513_filter
# 00514_finger
# 00515_fingerprint
# 00516_fire
# 00517_fire_alarm
# 00518_fire_hydrant
# 00519_fire_pit
# 00520_firecracker
# 00521_fireplace
# 00522_firetruck
# 00523_firewood
# 00524_fireworks
# 00525_first-aid_kit
# 00526_fish
# 00527_fishbowl
# 00528_fishhook
# 00529_fishing_pole
# 00530_fishnet_stockings
# 00531_flag
# 00532_flagpole
# 00533_flamethrower
# 00534_flan
# 00535_flashbulb
# 00536_flashlight
# 00537_flask
# 00538_flatiron
# 00539_flip_flop
# 00540_flipper
# 00541_float
# 00542_floss
# 00543_flour
# 00544_flower
# 00545_flute
# 00546_fly
# 00547_flypaper
# 00548_flyswatter
# 00549_foam
# 00550_fondue
# 00551_food_processor
# 00552_foot
# 00553_football
# 00554_football_helmet
# 00555_footbath
# 00556_footprint
# 00557_footrest
# 00558_forklift
# 00559_fossil
# 00560_fountain_pen
# 00561_fox
# 00562_frame
# 00563_french_fries
# 00564_frisbee
# 00565_frog
# 00566_fruitcake
# 00567_fudge
# 00568_fungus
# 00569_funnel
# 00570_fur_coat
# 00571_furnace
# 00572_fuse
# 00573_gallows
# 00574_game
# 00575_garbage
# 00576_garbage_truck
# 00577_gargoyle
# 00578_garter
# 00579_gas_mask
# 00580_gasket
# 00581_gate
# 00582_gauge
# 00583_gauze
# 00584_gavel
# 00585_gazelle
# 00586_gear
# 00587_gearshift
# 00588_gel
# 00589_gem
# 00590_generator
# 00591_gift
# 00592_ginger
# 00593_gingerbread_man
# 00594_giraffe
# 00595_girl
# 00596_glass
# 00597_glasses
# 00598_globe
# 00599_glue
# 00600_go-kart
# 00601_goalpost
# 00602_goat
# 00603_goblet
# 00604_goggles
# 00605_gold
# 00606_goldfish
# 00607_golf_club
# 00608_gong
# 00609_gourd
# 00610_graffiti
# 00611_grain
# 00612_gramophone
# 00613_granite
# 00614_granola
# 00615_grape
# 00616_grapefruit
# 00617_grapevine
# 00618_grass
# 00619_grate
# 00620_grater
# 00621_gravel
# 00622_gravestone
# 00623_gravy
# 00624_green_beans
# 00625_grill
# 00626_grille
# 00627_grinder
# 00628_grits
# 00629_groundhog
# 00630_guacamole
# 00631_guardrail
# 00632_guillotine
# 00633_guinea_pig
# 00634_guitar
# 00635_gum
# 00636_gumball
# 00637_gumdrop
# 00638_gun
# 00639_gurney
# 00640_gutter
# 00641_gyro
# 00642_gyroscope
# 00643_hail
# 00644_hair
# 00645_hairbrush
# 00646_hairdryer
# 00647_hairnet
# 00648_hairpin
# 00649_hairspray
# 00650_ham
# 00651_hammock
# 00652_hamster
# 00653_hand
# 00654_handcuff
# 00655_handkerchief
# 00656_handle
# 00657_handlebar
# 00658_handprint
# 00659_hanger
# 00660_hard_disk
# 00661_harmonica
# 00662_harness
# 00663_harp
# 00664_hash
# 00665_hat
# 00666_hatbox
# 00667_hatchet
# 00668_hawk
# 00669_hay
# 00670_headband
# 00671_headdress
# 00672_headlamp
# 00673_headlight
# 00674_headphones
# 00675_headrest
# 00676_headset
# 00677_hearing_aid
# 00678_hearse
# 00679_heater
# 00680_hedge
# 00681_hedgehog
# 00682_helicopter
# 00683_helmet
# 00684_highlighter
# 00685_hinge
# 00686_hip
# 00687_hippopotamus
# 00688_hobbyhorse
# 00689_hockey_stick
# 00690_hoe
# 00691_hole
# 00692_holster
# 00693_home_plate
# 00694_honey
# 00695_honeycomb
# 00696_honeypot
# 00697_hood
# 00698_hook1
# 00699_hook2
# 00700_hookah
# 00701_hopscotch
# 00702_horn
# 00703_horse
# 00704_horseshoe
# 00705_hose
# 00706_hot-air_balloon
# 00707_hot-water_bottle
# 00708_hot_chocolate
# 00709_hot_tub
# 00710_hotdog
# 00711_hotplate
# 00712_hourglass
# 00713_hovercraft
# 00714_hubcap
# 00715_hula_hoop
# 00716_hummus
# 00717_humvee
# 00718_hydrant
# 00719_hyena
# 00720_ice
# 00721_ice-cream_cone
# 00722_ice_cream
# 00723_icemaker
# 00724_icepick
# 00725_iceskate
# 00726_icicle
# 00727_iguana
# 00728_incense
# 00729_incubator
# 00730_inhaler
# 00731_ink
# 00732_inkwell
# 00733_insole
# 00734_iron
# 00735_ironing_board
# 00736_ivy
# 00737_jack
# 00738_jacket
# 00739_jackhammer
# 00740_jalapeno
# 00741_jam
# 00742_jar
# 00743_javelin
# 00744_jeans
# 00745_jellyfish
# 00746_jersey
# 00747_jet
# 00748_jetski
# 00749_jewel
# 00750_jewelry
# 00751_jigsaw_puzzle
# 00752_joystick
# 00753_jug
# 00754_juice
# 00755_juicer1
# 00756_juicer2
# 00757_jump_rope
# 00758_jumpsuit
# 00759_kale
# 00760_kaleidoscope
# 00761_kangaroo
# 00762_kayak
# 00763_kazoo
# 00764_kebab
# 00765_keg
# 00766_ketchup
# 00767_key
# 00768_keyboard
# 00769_keyhole
# 00770_kilt
# 00771_kimono
# 00772_kite
# 00773_kitten
# 00774_kiwi
# 00775_knee
# 00776_knife
# 00777_knitting
# 00778_knitting_needle
# 00779_knob
# 00780_knot
# 00781_koala
# 00782_lab_coat
# 00783_ladder
# 00784_ladybug
# 00785_lamb_chop
# 00786_lamp
# 00787_lamppost
# 00788_landmine
# 00789_lantern
# 00790_lanyard
# 00791_laptop
# 00792_lasagna
# 00793_laser_pointer
# 00794_latch
# 00795_latte
# 00796_lava
# 00797_lavender
# 00798_lawnmower
# 00799_leaf
# 00800_leash
# 00801_lectern
# 00802_leech
# 00803_leek
# 00804_leg
# 00805_leggings
# 00806_lego
# 00807_lemon
# 00808_lemonade
# 00809_lens
# 00810_leopard
# 00811_leotard
# 00812_letter_opener
# 00813_license_plate
# 00814_licorice
# 00815_lid
# 00816_life_jacket
# 00817_lifesaver
# 00818_light_switch
# 00819_lightbulb
# 00820_lighter
# 00821_lime
# 00822_limousine
# 00823_lingerie
# 00824_lion
# 00825_lip_balm
# 00826_lip_gloss
# 00827_lipstick
# 00828_lizard
# 00829_llama
# 00830_lobster
# 00831_lock
# 00832_locker
# 00833_locket
# 00834_log
# 00835_loincloth
# 00836_lollipop
# 00837_loom
# 00838_loveseat
# 00839_luggage
# 00840_lumber
# 00841_lunchbox
# 00842_macadamia
# 00843_macaroni
# 00844_machete
# 00845_machine_gun
# 00846_maggot
# 00847_magnet
# 00848_magnifier
# 00849_magnifying_glass
# 00850_mail
# 00851_mailbox
# 00852_makeup
# 00853_mallet
# 00854_man
# 00855_mandolin
# 00856_mango
# 00857_manhole
# 00858_mannequin
# 00859_mantle
# 00860_map
# 00861_maple_syrup
# 00862_marble
# 00863_margarita
# 00864_marker
# 00865_marmalade
# 00866_marshmallow
# 00867_mascara
# 00868_mashed_potato
# 00869_mask
# 00870_mast
# 00871_mat
# 00872_match
# 00873_matchbox
# 00874_mattress
# 00875_measuring_cup
# 00876_meat
# 00877_meat_grinder
# 00878_meatball
# 00879_medal
# 00880_meerkat
# 00881_megaphone
# 00882_melon
# 00883_memory_stick
# 00884_metronome
# 00885_microphone
# 00886_microscope
# 00887_microwave
# 00888_milk
# 00889_milkshake
# 00890_mint
# 00891_mirror
# 00892_missile
# 00893_mistletoe
# 00894_mitten
# 00895_mixer
# 00896_moccasin
# 00897_mold1
# 00898_mold2
# 00899_mole
# 00900_money
# 00901_mongoose
# 00902_monkey
# 00903_moose
# 00904_mop
# 00905_mosquito_net
# 00906_moss
# 00907_moth
# 00908_motherboard
# 00909_motorcycle
# 00910_mouse1
# 00911_mouse2
# 00912_mousepad
# 00913_mousetrap
# 00914_mousse
# 00915_mouth
# 00916_mouthpiece
# 00917_mud
# 00918_muffin
# 00919_mug
# 00920_mulberry
# 00921_mulch
# 00922_mullet
# 00923_mushroom
# 00924_mustache
# 00925_mustard
# 00926_nacho
# 00927_nail
# 00928_nail_clippers
# 00929_nail_file
# 00930_nail_polish
# 00931_napkin
# 00932_napkin_ring
# 00933_navel
# 00934_neck
# 00935_necklace
# 00936_needle
# 00937_nest
# 00938_net
# 00939_nightshirt
# 00940_noisemaker
# 00941_noodle
# 00942_noose
# 00943_nose
# 00944_notebook
# 00945_notepad
# 00946_nut
# 00947_nutcracker
# 00948_oar
# 00949_oatmeal
# 00950_octopus
# 00951_odometer
# 00952_oil
# 00953_oilcan
# 00954_olive
# 00955_orange_rind
# 00956_orangutan
# 00957_organ
# 00958_origami
# 00959_otter
# 00960_ottoman
# 00961_outfit
# 00962_outlet
# 00963_oven
# 00964_overalls
# 00965_owl
# 00966_oyster
# 00967_pacifier
# 00968_paddle
# 00969_padlock
# 00970_paint
# 00971_paintbrush
# 00972_painting
# 00973_palette
# 00974_pallet
# 00975_palm_tree
# 00976_pan
# 00977_pancake
# 00978_panda
# 00979_panties
# 00980_pants
# 00981_pantsuit
# 00982_pantyhose
# 00983_papaya
# 00984_paper
# 00985_paper_bag
# 00986_paper_plate
# 00987_paper_towel
# 00988_paperclip
# 00989_parachute
# 00990_parfait
# 00991_parking_meter
# 00992_parrot
# 00993_parsley
# 00994_pasta
# 00995_pastry
# 00996_patch
# 00997_patty
# 00998_payphone
# 00999_pea
# 01000_peach
# 01001_peacock
# 01002_peanut
# 01003_peanut_butter
# 01004_pearl
# 01005_pecan
# 01006_pedal
# 01007_pedometer
# 01008_peeler
# 01009_peg
# 01010_pelican
# 01011_pen
# 01012_pencil
# 01013_pencil_sharpener
# 01014_pendulum
# 01015_penguin
# 01016_penholder
# 01017_penlight
# 01018_pennant
# 01019_pepper2
# 01020_pepper_mill
# 01021_peppermint
# 01022_pepperoni
# 01023_perfume
# 01024_periscope
# 01025_pesto
# 01026_pet_food
# 01027_petal
# 01028_petri_dish
# 01029_phone
# 01030_phone_booth
# 01031_photo_booth
# 01032_photograph
# 01033_piano
# 01034_pickle
# 01035_piecrust
# 01036_pig
# 01037_piggy_bank
# 01038_pill
# 01039_pillbox
# 01040_pillow
# 01041_pin
# 01042_pinball
# 01043_pincushion
# 01044_pine_needle
# 01045_pine_tree
# 01046_pineapple
# 01047_pinecone
# 01048_ping-pong_table
# 01049_pinwheel
# 01050_pipe1
# 01051_pipe2
# 01052_pistachio
# 01053_pita
# 01054_pitcher
# 01055_pitchfork
# 01056_pizza
# 01057_place_mat
# 01058_plant
# 01059_plaster_cast
# 01060_plastic_film
# 01061_plate
# 01062_platypus
# 01063_playing_card
# 01064_playpen
# 01065_pliers
# 01066_plug
# 01067_plum
# 01068_plunger
# 01069_pocket_watch
# 01070_pogo_stick
# 01071_poinsettia
# 01072_poker
# 01073_polar_bear
# 01074_polaroid
# 01075_pole
# 01076_police_car
# 01077_polisher
# 01078_polo_shirt
# 01079_polygraph
# 01080_pom-pom
# 01081_pomegranate
# 01082_pony
# 01083_poodle
# 01084_pool_table
# 01085_poppy
# 01086_porcupine
# 01087_porthole
# 01088_poster
# 01089_pot
# 01090_potato
# 01091_potholder
# 01092_pothole
# 01093_potpie
# 01094_potpourri
# 01095_powder
# 01096_power_line
# 01097_praying_mantis
# 01098_printer
# 01099_prism
# 01100_projector
# 01101_propeller
# 01102_prune
# 01103_puck
# 01104_pudding
# 01105_puddle
# 01106_puffin
# 01107_pulley
# 01108_pulpit
# 01109_pump
# 01110_pumpkin
# 01111_punch1
# 01112_punching_bag
# 01113_puppet
# 01114_puppy
# 01115_quad
# 01116_quesadilla
# 01117_quiche
# 01118_quill
# 01119_quilt
# 01120_rabbit
# 01121_raccoon
# 01122_racehorse
# 01123_rack1
# 01124_rack2
# 01125_racket
# 01126_radar
# 01127_radiator
# 01128_radio
# 01129_raft
# 01130_rag
# 01131_railing
# 01132_rain_gauge
# 01133_raincoat
# 01134_raisin
# 01135_rake
# 01136_ram
# 01137_ramp
# 01138_rat
# 01139_ratchet
# 01140_rattle
# 01141_rattlesnake
# 01142_ravioli
# 01143_razor
# 01144_razor_blade
# 01145_ready_meal
# 01146_rearview_mirror
# 01147_recliner
# 01148_record
# 01149_record_player
# 01150_red_carpet
# 01151_reel
# 01152_refrigerator
# 01153_reindeer
# 01154_remote_control
# 01155_retainer
# 01156_revolver
# 01157_revolving_door
# 01158_rhubarb
# 01159_ribbon
# 01160_rice
# 01161_rickshaw
# 01162_rifle
# 01163_rim
# 01164_ring
# 01165_riser
# 01166_road_sign
# 01167_roadsweeper
# 01168_robe
# 01169_rock
# 01170_rocket
# 01171_rocking_chair
# 01172_rocking_horse
# 01173_roll
# 01174_roller
# 01175_roller_coaster
# 01176_rollerblade
# 01177_rollerskate
# 01178_rolling_pin
# 01179_roof_rack
# 01180_root
# 01181_rope
# 01182_rosary
# 01183_rose
# 01184_roulette_wheel
# 01185_router
# 01186_rubber_band
# 01187_ruby
# 01188_rudder
# 01189_ruler
# 01190_rust
# 01191_saddle
# 01192_safety_pin
# 01193_saffron
# 01194_sail
# 01195_salad
# 01196_salami
# 01197_saltshaker
# 01198_sand
# 01199_sandbag
# 01200_sandbox
# 01201_sandcastle
# 01202_sandwich
# 01203_sarcophagus
# 01204_sardine
# 01205_satellite
# 01206_satellite_dish
# 01207_sauce
# 01208_saucer
# 01209_sauerkraut
# 01210_saw
# 01211_sawhorse
# 01212_saxophone
# 01213_scaffold
# 01214_scaffolding
# 01215_scale
# 01216_scalpel
# 01217_scanner
# 01218_scarecrow
# 01219_scarf
# 01220_school_bus
# 01221_scissors
# 01222_scone
# 01223_scoop
# 01224_scoreboard
# 01225_scorpion
# 01226_scrabble
# 01227_scrambled_egg
# 01228_scraper
# 01229_screen1
# 01230_screen2
# 01231_screw
# 01232_screwdriver
# 01233_scuba
# 01234_sea_urchin
# 01235_seafood
# 01236_seahorse
# 01237_seal
# 01238_seaplane
# 01239_seatbelt
# 01240_seesaw
# 01241_seismograph
# 01242_sequin
# 01243_sewage
# 01244_sewing_kit
# 01245_sewing_machine
# 01246_shaker
# 01247_shark
# 01248_shaving_cream
# 01249_shawl
# 01250_shears
# 01251_sheath
# 01252_sheep
# 01253_sheet
# 01254_shelf
# 01255_shell1
# 01256_shell2
# 01257_shell3
# 01258_shield
# 01259_ship
# 01260_shirt
# 01261_shoe
# 01262_shoe_polish
# 01263_shoehorn
# 01264_shoelace
# 01265_shopping_basket
# 01266_shopping_cart
# 01267_shortbread
# 01268_shorts
# 01269_shoulder
# 01270_shovel
# 01271_shower
# 01272_shower_cap
# 01273_shower_curtain
# 01274_showerhead
# 01275_shredder
# 01276_shrimp
# 01277_shuffleboard
# 01278_shutter
# 01279_sickle
# 01280_sidecar
# 01281_sifter
# 01282_silicone
# 01283_silverware
# 01284_sim_card
# 01285_sink
# 01286_siren
# 01287_skeleton
# 01288_skewer
# 01289_ski
# 01290_ski_boots
# 01291_ski_lift
# 01292_ski_pole
# 01293_skin
# 01294_skirt
# 01295_skull
# 01296_skunk
# 01297_sledgehammer
# 01298_slicer
# 01299_slime
# 01300_sling
# 01301_slipper
# 01302_slot
# 01303_slot_machine
# 01304_sloth
# 01305_slug
# 01306_smoke_alarm
# 01307_smoothie
# 01308_snack
# 01309_snail
# 01310_snake
# 01311_snorkel
# 01312_snow
# 01313_snowball
# 01314_snowboard
# 01315_snowman
# 01316_snowmobile
# 01317_snowplow
# 01318_snowsuit
# 01319_soap
# 01320_soccer_ball
# 01321_sock
# 01322_soda
# 01323_soda_fountain
# 01324_sofa_bed
# 01325_solar_panel
# 01326_soldering_iron
# 01327_sombrero
# 01328_sonogram
# 01329_sorbet
# 01330_souffle
# 01331_soup
# 01332_soy_sauce
# 01333_space_shuttle
# 01334_spacesuit
# 01335_spaghetti
# 01336_spam
# 01337_spareribs
# 01338_spark_plug
# 01339_sparkler
# 01340_speaker
# 01341_spear
# 01342_speedboat
# 01343_speedometer
# 01344_spider
# 01345_spider_web
# 01346_spinach
# 01347_splinter
# 01348_sponge
# 01349_spool
# 01350_spout
# 01351_spring_roll
# 01352_springboard
# 01353_sprinkler
# 01354_sprouts
# 01355_spur
# 01356_squash
# 01357_squeegee
# 01358_squid
# 01359_squirrel
# 01360_squirt_gun
# 01361_stained_glass
# 01362_stair
# 01363_stake
# 01364_stalagmite
# 01365_stamp1
# 01366_stamp2
# 01367_staple
# 01368_staple_gun
# 01369_stapler
# 01370_star_fruit
# 01371_starfish
# 01372_statue
# 01373_steak
# 01374_steamroller
# 01375_steering_wheel
# 01376_stem
# 01377_step_stool
# 01378_stereo
# 01379_stew
# 01380_stick
# 01381_sticker
# 01382_stiletto
# 01383_stilt
# 01384_stingray
# 01385_stir_fry
# 01386_stirrup
# 01387_stockings
# 01388_stomach
# 01389_stool
# 01390_stopwatch
# 01391_stove1
# 01392_stove2
# 01393_straightjacket
# 01394_strainer
# 01395_strap
# 01396_straw1
# 01397_straw2
# 01398_streetlight
# 01399_stretcher
# 01400_string_cheese
# 01401_stroller
# 01402_stuffing
# 01403_stump
# 01404_subway
# 01405_sugar_cube
# 01406_suitcase
# 01407_sundae
# 01408_sundial
# 01409_sunflower
# 01410_sunglasses
# 01411_sunroof
# 01412_surfboard
# 01413_sushi
# 01414_suspenders
# 01415_swab
# 01416_swan
# 01417_sweater
# 01418_sweatsuit
# 01419_sweeper
# 01420_sweet_potato
# 01421_swimming_pool
# 01422_swimsuit
# 01423_swing
# 01424_swing_set
# 01425_switch
# 01426_swizzle_stick
# 01427_sword
# 01428_swordfish
# 01429_syringe
# 01430_syrup
# 01431_tab
# 01432_tablecloth
# 01433_tablet
# 01434_tack
# 01435_tackle
# 01436_taco
# 01437_tadpole
# 01438_taffy
# 01439_tag
# 01440_tamale
# 01441_tambourine
# 01442_tank1
# 01443_tank2
# 01444_tape
# 01445_tape_measure
# 01446_tapestry
# 01447_tarantula
# 01448_target
# 01449_tarp
# 01450_tattoo
# 01451_taxi
# 01452_tea
# 01453_teabag
# 01454_teacup
# 01455_teapot
# 01456_teddy_bear
# 01457_tee
# 01458_teepee
# 01459_telegraph
# 01460_telephone_pole
# 01461_telescope
# 01462_tennis_ball
# 01463_tent
# 01464_terrarium
# 01465_test_tube
# 01466_thermometer
# 01467_thermos
# 01468_thermostat
# 01469_thimble
# 01470_thorn
# 01471_thread
# 01472_throne
# 01473_thumb
# 01474_thumbtack
# 01475_ticktacktoe
# 01476_tie
# 01477_tiger
# 01478_tile
# 01479_timer
# 01480_tinsel
# 01481_tiramisu
# 01482_toad
# 01483_toast
# 01484_toaster
# 01485_toaster_oven
# 01486_toe
# 01487_toga
# 01488_toilet
# 01489_toilet_paper
# 01490_tomato
# 01491_tongue
# 01492_toolbox
# 01493_tooth
# 01494_toothbrush
# 01495_toothpaste
# 01496_toothpick
# 01497_torch
# 01498_torpedo
# 01499_torso
# 01500_tortellini
# 01501_tortilla
# 01502_tostada
# 01503_totem_pole
# 01504_toucan
# 01505_touchpad
# 01506_towel
# 01507_towel_rack
# 01508_toy
# 01509_tractor
# 01510_traffic_light
# 01511_trailer
# 01512_train
# 01513_train_car
# 01514_train_set
# 01515_trampoline
# 01516_trap
# 01517_trapdoor
# 01518_trashcan
# 01519_tray
# 01520_treasure
# 01521_tree
# 01522_tree_trunk
# 01523_triangle
# 01524_tricycle
# 01525_trident
# 01526_trigger
# 01527_tripod
# 01528_trolley
# 01529_trombone
# 01530_trophy
# 01531_trough
# 01532_trowel
# 01533_truck
# 01534_trumpet
# 01535_trunk
# 01536_tuba
# 01537_tugboat
# 01538_tulip
# 01539_tumbleweed
# 01540_tuning_fork
# 01541_tupperware
# 01542_turban
# 01543_turbine
# 01544_turf
# 01545_turnstile
# 01546_turntable
# 01547_turtle
# 01548_turtleneck
# 01549_tuxedo
# 01550_tweezers
# 01551_twig
# 01552_typewriter
# 01553_ukulele
# 01554_umbrella
# 01555_undershirt
# 01556_underwear
# 01557_uniform
# 01558_urinal
# 01559_urn
# 01560_vacuum
# 01561_valve
# 01562_van
# 01563_vase
# 01564_vegetable
# 01565_veil
# 01566_velcro
# 01567_vending_machine
# 01568_vent
# 01569_vest
# 01570_vial
# 01571_videocassette
# 01572_videogame
# 01573_viewfinder
# 01574_violin
# 01575_visor
# 01576_vulture
# 01577_wafer
# 01578_waffle
# 01579_waffle_iron
# 01580_wagon
# 01581_walker1
# 01582_walker2
# 01583_wall
# 01584_wallet
# 01585_walrus
# 01586_wand
# 01587_warthog
# 01588_washboard
# 01589_washcloth
# 01590_washing_machine
# 01591_wasp
# 01592_watch
# 01593_water_bottle
# 01594_water_cooler
# 01595_water_filter
# 01596_water_fountain
# 01597_water_heater
# 01598_watering_can
# 01599_watermelon
# 01600_waterwheel
# 01601_wax
# 01602_wax_paper
# 01603_weasel
# 01604_weather_vane
# 01605_webcam
# 01606_wedding_cake
# 01607_wedge
# 01608_weed
# 01609_wetsuit
# 01610_whale
# 01611_wheel
# 01612_wheelbarrow
# 01613_whip
# 01614_whipped_cream
# 01615_whisk
# 01616_whistle
# 01617_whiteboard
# 01618_whoopee_cushion
# 01619_wick
# 01620_wig
# 01621_wind_chimes
# 01622_window
# 01623_windowsill
# 01624_windshield_wiper
# 01625_windsock
# 01626_wine_bottle
# 01627_wine_cooler
# 01628_wineglass
# 01629_wing
# 01630_wire
# 01631_wire_cutters
# 01632_wolf
# 01633_woman
# 01634_wood
# 01635_wooden_leg
# 01636_workbench
# 01637_worm
# 01638_wrap
# 01639_wrapping_paper
# 01640_wreath
# 01641_wreck
# 01642_wrench
# 01643_wrist
# 01644_xylophone
# 01645_yacht
# 01646_yak
# 01647_yarn
# 01648_yo-yo
# 01649_yogurt
# 01650_yoke
# 01651_yolk
# 01652_zebra
# 01653_zipper
# 01654_zucchini

# %%
mmbracategories.print_unseen_categories()
# Out:
# 00001_aircraft_carrier
# 00002_antelope
# 00003_backscratcher
# 00004_balance_beam
# 00005_banana
# 00006_baseball_bat
# 00007_basil
# 00008_basketball
# 00009_bassoon
# 00010_baton4
# 00011_batter
# 00012_beaver
# 00013_bench
# 00014_bike
# 00015_birthday_cake
# 00016_blowtorch
# 00017_boat
# 00018_bok_choy
# 00019_bonnet
# 00020_bottle_opener
# 00021_brace
# 00022_bread
# 00023_breadbox
# 00024_bug
# 00025_buggy
# 00026_bullet
# 00027_bun
# 00028_bush
# 00029_calamari
# 00030_candlestick
# 00031_cart
# 00032_cashew
# 00033_cat
# 00034_caterpillar
# 00035_cd_player
# 00036_chain
# 00037_chaps
# 00038_cheese
# 00039_cheetah
# 00040_chest2
# 00041_chime
# 00042_chopsticks
# 00043_cleat
# 00044_cleaver
# 00045_coat
# 00046_cobra
# 00047_coconut
# 00048_coffee_bean
# 00049_coffeemaker
# 00050_cookie
# 00051_cordon_bleu
# 00052_coverall
# 00053_crab
# 00054_creme_brulee
# 00055_crepe
# 00056_crib
# 00057_croissant
# 00058_crow
# 00059_cruise_ship
# 00060_crumb
# 00061_cupcake
# 00062_dagger
# 00063_dalmatian
# 00064_dessert
# 00065_dragonfly
# 00066_dreidel
# 00067_drum
# 00068_duffel_bag
# 00069_eagle
# 00070_eel
# 00071_egg
# 00072_elephant
# 00073_espresso
# 00074_face_mask
# 00075_ferry
# 00076_flamingo
# 00077_folder
# 00078_fork
# 00079_freezer
# 00080_french_horn
# 00081_fruit
# 00082_garlic
# 00083_glove
# 00084_golf_cart
# 00085_gondola
# 00086_goose
# 00087_gopher
# 00088_gorilla
# 00089_grasshopper
# 00090_grenade
# 00091_hamburger
# 00092_hammer
# 00093_handbrake
# 00094_headscarf
# 00095_highchair
# 00096_hoodie
# 00097_hummingbird
# 00098_ice_cube
# 00099_ice_pack
# 00100_jeep
# 00101_jelly_bean
# 00102_jukebox
# 00103_kettle
# 00104_kneepad
# 00105_ladle
# 00106_lamb
# 00107_lampshade
# 00108_laundry_basket
# 00109_lettuce
# 00110_lightning_bug
# 00111_manatee
# 00112_marijuana
# 00113_meatloaf
# 00114_metal_detector
# 00115_minivan
# 00116_modem
# 00117_mosquito
# 00118_muff
# 00119_music_box
# 00120_mussel
# 00121_nightstand
# 00122_okra
# 00123_omelet
# 00124_onion
# 00125_orange
# 00126_orchid
# 00127_ostrich
# 00128_pajamas
# 00129_panther
# 00130_paperweight
# 00131_pear
# 00132_pepper1
# 00133_pheasant
# 00134_pickax
# 00135_pie
# 00136_pigeon
# 00137_piglet
# 00138_pocket
# 00139_pocketknife
# 00140_popcorn
# 00141_popsicle
# 00142_possum
# 00143_pretzel
# 00144_pug
# 00145_punch2
# 00146_purse
# 00147_radish
# 00148_raspberry
# 00149_recorder
# 00150_rhinoceros
# 00151_robot
# 00152_rooster
# 00153_rug
# 00154_sailboat
# 00155_sandal
# 00156_sandpaper
# 00157_sausage
# 00158_scallion
# 00159_scallop
# 00160_scooter
# 00161_seagull
# 00162_seaweed
# 00163_seed
# 00164_skateboard
# 00165_sled
# 00166_sleeping_bag
# 00167_slide
# 00168_slingshot
# 00169_snowshoe
# 00170_spatula
# 00171_spoon
# 00172_station_wagon
# 00173_stethoscope
# 00174_strawberry
# 00175_submarine
# 00176_suit
# 00177_t-shirt
# 00178_table
# 00179_taillight
# 00180_tape_recorder
# 00181_television
# 00182_tiara
# 00183_tick
# 00184_tomato_sauce
# 00185_tongs
# 00186_tool
# 00187_top_hat
# 00188_treadmill
# 00189_tube_top
# 00190_turkey
# 00191_unicycle
# 00192_vise
# 00193_volleyball
# 00194_wallpaper
# 00195_walnut
# 00196_wheat
# 00197_wheelchair
# 00198_windshield
# 00199_wine
# 00200_wok
